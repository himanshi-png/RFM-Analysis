# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib
import matplotlib.pyplot as plt
import piplite
#await piplite.install('seaborn')
#import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %%
print(df)
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365     71053                  WHITE METAL LANTERN         6
# 2        536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...         ...       ...                                  ...       ...
# 37304    539456    85135C             RED DRAGONFLY HELICOPTER         2
# 37305    539456     22095                 LADS ONLY TISSUE BOX         1
# 37306    539456   15056BL              EDWARDIAN PARASOL BLACK         1
# 37307    539456     20679                EDWARDIAN PARASOL RED         1
# 37308    539456    85136A              YELLOW SHARK HELICOPTER         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 37304  12/17/2010 17:23       7.95     16885.0  United Kingdom
# 37305  12/17/2010 17:23       1.25     16885.0  United Kingdom
# 37306  12/17/2010 17:23       5.95     16885.0  United Kingdom
# 37307  12/17/2010 17:23       5.95     16885.0  United Kingdom
# 37308          12/17/20        NaN         NaN             NaN
#
# [37309 rows x 8 columns]

# %%
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37309 entries, 0 to 37308
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    37309 non-null  object
#  1   StockCode    37309 non-null  object
#  2   Description  37192 non-null  object
#  3   Quantity     37309 non-null  int64
#  4   InvoiceDate  37309 non-null  object
#  5   UnitPrice    37308 non-null  float64
#  6   CustomerID   24429 non-null  float64
#  7   Country      37308 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1.6+ MB

# %%
table1=df[['InvoiceNo','CustomerID','InvoiceDate','UnitPrice','Quantity','Country']]

# %%
table1['Sales']=table1['UnitPrice']*table1['Quantity']
table1['InvoiceDate']=pd.to_datetime(table1['InvoiceDate'])
table2=table1.dropna()
table2.info()
# Out:
# <ipython-input-208-14487c168989>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table1['Sales']=table1['UnitPrice']*table1['Quantity']
# <ipython-input-208-14487c168989>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table1['InvoiceDate']=pd.to_datetime(table1['InvoiceDate'])
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24429 entries, 0 to 37307
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    24429 non-null  object
#  1   CustomerID   24429 non-null  float64
#  2   InvoiceDate  24429 non-null  datetime64[ns]
#  3   UnitPrice    24429 non-null  float64
#  4   Quantity     24429 non-null  int64
#  5   Country      24429 non-null  object
#  6   Sales        24429 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 1.3+ MB

# %%
table1[table1.CustomerID==12347.0]
# Out:
#       InvoiceNo  CustomerID         InvoiceDate  UnitPrice  Quantity  Country  \
# 14938    537626     12347.0 2010-12-07 14:57:00       2.10        12  Iceland
# 14939    537626     12347.0 2010-12-07 14:57:00       4.25         4  Iceland
# 14940    537626     12347.0 2010-12-07 14:57:00       3.25        12  Iceland
# 14941    537626     12347.0 2010-12-07 14:57:00       0.65        36  Iceland
# 14942    537626     12347.0 2010-12-07 14:57:00       1.25        12  Iceland
# 14943    537626     12347.0 2010-12-07 14:57:00       1.25        12  Iceland
# 14944    537626     12347.0 2010-12-07 14:57:00       1.25        12  Iceland
# 14945    537626     12347.0 2010-12-07 14:57:00       1.25        12  Iceland
# 14946    537626     12347.0 2010-12-07 14:57:00       1.25        12  Iceland
# 14947    537626     12347.0 2010-12-07 14:57:00       1.25        12  Iceland
# 14948    537626     12347.0 2010-12-07 14:57:00       3.75         4  Iceland
# 14949    537626     12347.0 2010-12-07 14:57:00       3.75         4  Iceland
# 14950    537626     12347.0 2010-12-07 14:57:00       3.75         4  Iceland
# 14951    537626     12347.0 2010-12-07 14:57:00       3.75         4  Iceland
# 14952    537626     12347.0 2010-12-07 14:57:00       3.75         4  Iceland
# 14953    537626     12347.0 2010-12-07 14:57:00       2.10         6  Iceland
# 14954    537626     12347.0 2010-12-07 14:57:00       1.25        30  Iceland
# 14955    537626     12347.0 2010-12-07 14:57:00       1.45        12  Iceland
# 14956    537626     12347.0 2010-12-07 14:57:00       1.65        12  Iceland
# 14957    537626     12347.0 2010-12-07 14:57:00       4.25         6  Iceland
# 14958    537626     12347.0 2010-12-07 14:57:00       3.75         6  Iceland
# 14959    537626     12347.0 2010-12-07 14:57:00       3.75         6  Iceland
# 14960    537626     12347.0 2010-12-07 14:57:00       3.75         6  Iceland
# 14961    537626     12347.0 2010-12-07 14:57:00       1.25        12  Iceland
# 14962    537626     12347.0 2010-12-07 14:57:00       4.25         4  Iceland
# 14963    537626     12347.0 2010-12-07 14:57:00       4.95         3  Iceland
# 14964    537626     12347.0 2010-12-07 14:57:00       5.95         6  Iceland
# 14965    537626     12347.0 2010-12-07 14:57:00       1.65        12  Iceland
# 14966    537626     12347.0 2010-12-07 14:57:00       2.95        24  Iceland
# 14967    537626     12347.0 2010-12-07 14:57:00       4.65        12  Iceland
# 14968    537626     12347.0 2010-12-07 14:57:00       5.49         6  Iceland
#
#        Sales
# 14938  25.20
# 14939  17.00
# 14940  39.00
# 14941  23.40
# 14942  15.00
# 14943  15.00
# 14944  15.00
# 14945  15.00
# 14946  15.00
# 14947  15.00
# 14948  15.00
# 14949  15.00
# 14950  15.00
# 14951  15.00
# 14952  15.00
# 14953  12.60
# 14954  37.50
# 14955  17.40
# 14956  19.80
# 14957  25.50
# 14958  22.50
# 14959  22.50
# 14960  22.50
# 14961  15.00
# 14962  17.00
# 14963  14.85
# 14964  35.70
# 14965  19.80
# 14966  70.80
# 14967  55.80
# 14968  32.94

# %%
now=datetime.now()
df_recency=table2[['CustomerID','InvoiceDate']].copy()
df_recency.groupby('CustomerID').agg({'InvoiceDate':['max']})
df2=df_recency.drop_duplicates(subset='CustomerID')
df2
# Out:
#        CustomerID         InvoiceDate
# 0         17850.0 2010-12-01 08:26:00
# 9         13047.0 2010-12-01 08:34:00
# 26        12583.0 2010-12-01 08:45:00
# 46        13748.0 2010-12-01 09:00:00
# 65        15100.0 2010-12-01 09:09:00
# ...           ...                 ...
# 35206     12691.0 2010-12-17 14:46:00
# 36166     13869.0 2010-12-17 15:14:00
# 36210     14146.0 2010-12-17 15:52:00
# 36251     12705.0 2010-12-17 15:58:00
# 37280     16885.0 2010-12-17 17:23:00
#
# [898 rows x 2 columns]

# %%
df2['Recency']=(now-df2.InvoiceDate).dt.days
Recency=df2.drop('InvoiceDate',axis=1)
Recency
# Out:
# <ipython-input-211-73a586afbada>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Recency']=(now-df2.InvoiceDate).dt.days
#        CustomerID  Recency
# 0         17850.0     4595
# 9         13047.0     4595
# 26        12583.0     4595
# 46        13748.0     4595
# 65        15100.0     4595
# ...           ...      ...
# 35206     12691.0     4579
# 36166     13869.0     4579
# 36210     14146.0     4579
# 36251     12705.0     4579
# 37280     16885.0     4579
#
# [898 rows x 2 columns]

# %%
df_monetary=table2[['CustomerID','Sales']].copy()
Monetary=df_monetary.groupby('CustomerID',sort=False).sum().reset_index()
Monetary
# Out:
#      CustomerID    Sales
# 0       17850.0  5391.21
# 1       13047.0   366.63
# 2       12583.0   855.86
# 3       13748.0   204.00
# 4       15100.0   492.75
# ..          ...      ...
# 893     12691.0   180.00
# 894     13869.0   323.62
# 895     14146.0  1241.43
# 896     12705.0   858.00
# 897     16885.0   176.80
#
# [898 rows x 2 columns]

# %%
df2=table2[['CustomerID','InvoiceNo']].copy()
Frequency=df2.groupby(['CustomerID'],sort=False)['InvoiceNo'].count().reset_index()
Frequency
# Out:
#      CustomerID  InvoiceNo
# 0       17850.0        297
# 1       13047.0         17
# 2       12583.0         20
# 3       13748.0          1
# 4       15100.0          4
# ..          ...        ...
# 893     12691.0          5
# 894     13869.0         21
# 895     14146.0         35
# 896     12705.0         30
# 897     16885.0         28
#
# [898 rows x 2 columns]

# %%
df_rfm=Monetary.merge(Recency,on='CustomerID',how='left')
df_rfm=Frequency.merge(df_rm,on='CustomerID',how='left')
df_rfm.rename(columns={'InvoiceNo':'Frequency','Sales':'Monetary','InvoiceDate':'Recency'},inplace=True)
df_rfm
# Out:
#      CustomerID  Frequency  Monetary  Recency
# 0       17850.0        297   5391.21     4594
# 1       13047.0         17    366.63     4595
# 2       12583.0         20    855.86     4595
# 3       13748.0          1    204.00     4595
# 4       15100.0          4    492.75     4580
# ..          ...        ...       ...      ...
# 893     12691.0          5    180.00     4579
# 894     13869.0         21    323.62     4579
# 895     14146.0         35   1241.43     4579
# 896     12705.0         30    858.00     4579
# 897     16885.0         28    176.80     4579
#
# [898 rows x 4 columns]

# %%
#df_rfm.info()
df_rfm['r_score']=pd.qcut(df_rfm['Recency'], q=5, labels=[1, 2, 3, 4, 5])
df_rfm['f_score']=pd.qcut(df_rfm['Frequency'], q=5, labels=[1, 2, 3, 4, 5])
df_rfm['m_score']=pd.qcut(df_rfm['Monetary'], q=5, labels=[1, 2, 3, 4, 5])
df_rfm['RFM_score']=df_rfm['r_score'].astype(str) +df_rfm["f_score"].astype(str) + df_rfm["m_score"].astype(str)
df_rfm
# Out:
#      CustomerID  Frequency  Monetary  Recency r_score f_score m_score  \
# 0       17850.0        297   5391.21     4594       5       5       5
# 1       13047.0         17    366.63     4595       5       3       4
# 2       12583.0         20    855.86     4595       5       3       5
# 3       13748.0          1    204.00     4595       5       1       2
# 4       15100.0          4    492.75     4580       1       1       4
# ..          ...        ...       ...      ...     ...     ...     ...
# 893     12691.0          5    180.00     4579       1       1       2
# 894     13869.0         21    323.62     4579       1       3       3
# 895     14146.0         35   1241.43     4579       1       4       5
# 896     12705.0         30    858.00     4579       1       4       5
# 897     16885.0         28    176.80     4579       1       4       2
#
#     RFM_score
# 0         555
# 1         534
# 2         535
# 3         512
# 4         114
# ..        ...
# 893       112
# 894       133
# 895       145
# 896       145
# 897       142
#
# [898 rows x 8 columns]

# %%
seg_map = {
    r'[1-2][1-2]': 'Hibernating',
    r'[1-2][3-4]': 'At Risk',
    r'[1-2]5': 'Can\'t Loose',
    r'3[1-2]': 'About to Sleep',
    r'33': 'Need Attention',
    r'[3-4][4-5]': 'Loyal Customers',
    r'41': 'Promising',
    r'51': 'New Customers',
    r'[4-5][2-3]': 'Potential Loyalists',
    r'5[4-5]': 'Champions'
}

# %%
df_rfm['Segment'] = df_rfm['r_score'].astype(str) + df_rfm['f_score'].astype(str)
df_rfm['Segment'] = df_rfm['Segment'].replace(seg_map, regex=True)
df_rfm.head()
# Out:
#    CustomerID  Frequency  Monetary  Recency r_score f_score m_score RFM_score  \
# 0     17850.0        297   5391.21     4594       5       5       5       555
# 1     13047.0         17    366.63     4595       5       3       4       534
# 2     12583.0         20    855.86     4595       5       3       5       535
# 3     13748.0          1    204.00     4595       5       1       2       512
# 4     15100.0          4    492.75     4580       1       1       4       114
#
#                Segment
# 0            Champions
# 1  Potential Loyalists
# 2  Potential Loyalists
# 3        New Customers
# 4          Hibernating

# %%
df_segment=df_rfm.assign(Country=table1.Country,CustomerID=table1.CustomerID)
df_segment
# Out:
#      CustomerID  Frequency  Monetary  Recency r_score f_score m_score  \
# 0       17850.0        297   5391.21     4594       5       5       5
# 1       17850.0         17    366.63     4595       5       3       4
# 2       17850.0         20    855.86     4595       5       3       5
# 3       17850.0          1    204.00     4595       5       1       2
# 4       17850.0          4    492.75     4580       1       1       4
# ..          ...        ...       ...      ...     ...     ...     ...
# 893     17897.0          5    180.00     4579       1       1       2
# 894     17897.0         21    323.62     4579       1       3       3
# 895     17897.0         35   1241.43     4579       1       4       5
# 896     17897.0         30    858.00     4579       1       4       5
# 897     17897.0         28    176.80     4579       1       4       2
#
#     RFM_score              Segment         Country
# 0         555            Champions  United Kingdom
# 1         534  Potential Loyalists  United Kingdom
# 2         535  Potential Loyalists  United Kingdom
# 3         512        New Customers  United Kingdom
# 4         114          Hibernating  United Kingdom
# ..        ...                  ...             ...
# 893       112          Hibernating  United Kingdom
# 894       133              At Risk  United Kingdom
# 895       145              At Risk  United Kingdom
# 896       145              At Risk  United Kingdom
# 897       142              At Risk  United Kingdom
#
# [898 rows x 10 columns]

# %%
w=df_segment.groupby(['Segment','Country'])['CustomerID'].count()
w
# Out:
# Segment              Country
# About to Sleep       United Kingdom     94
# At Risk              Australia           2
#                      France              2
#                      United Kingdom    141
# Can't Loose          France              3
#                      United Kingdom     82
# Champions            Australia           4
#                      France              5
#                      United Kingdom     32
# Hibernating          United Kingdom    143
# Loyal Customers      France              3
#                      United Kingdom    153
# Need Attention       United Kingdom     44
# New Customers        Australia           4
#                      France              5
#                      United Kingdom     35
# Potential Loyalists  Australia           4
#                      France              2
#                      United Kingdom    109
# Promising            Netherlands         2
#                      United Kingdom     28
# Name: CustomerID, dtype: int64

# %%
df_segment.groupby(['Segment','Country'])['CustomerID'].count().unstack().plot(kind='bar',stacked='True')
# Out:
# <AxesSubplot:xlabel='Segment'>
